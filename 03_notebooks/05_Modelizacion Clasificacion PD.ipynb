# %% [markdown]
# # MODELIZACIÓN CLASIFICACIÓN PROBABILITY OF DEFAULT

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import os
from pathlib import Path
import openpyxl
import sqlalchemy as sa

# Desactivar notación científica
pd.set_option('display.float_format', lambda x: '%.3f' % x)
np.set_printoptions(suppress=True)

# Cargar variables de entorno
load_dotenv()

print("✅ Librerías importadas correctamente")
# Out:
# ✅ Librerías importadas correctamente

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %%
df = pd.read_pickle('../02_datos/03_Entrenamiento/df_tablon_pd.pkl')

# %%
x = df.drop(columns='target_pd')
y = df.target_pd

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
from sklearn.model_selection import train_test_split
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %% [markdown]
# Modificar para dejar solo los algoritmos que se quieran testar.
#
# Modificar los parámetros.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipe = Pipeline([('algoritmo',LogisticRegression())])

grid = [{'algoritmo': [LogisticRegression(solver = 'saga')],
         'algoritmo__l1_ratio': [0, 0.5, 1],
         'algoritmo__C': [0.01,0.25,0.5,0.75,1]}
       ]

# %% [markdown]
# ### Optimizar los hiper parámetros

# %% [markdown]
# Elegir si se quiere usar grid search o random search.
#
# Comentar la opción que no se vaya a usar.

# %% [markdown]
# ####  Con grid search

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(estimator= pipe, 
                           param_grid = grid, 
                           cv = 5, 
                           scoring = 'roc_auc',
                           verbose = 0,
                           n_jobs = -1)

modelo = grid_search.fit(train_x,train_y)

# %%
salida = pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score').reset_index(drop=True).head(5)
salida
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          3.489         0.846            0.022           0.001
# 1          9.756         1.448            0.024           0.002
# 2          8.107         0.212            0.024           0.001
# 3          4.179         2.560            0.026           0.005
# 4          7.775         0.777            0.024           0.001
#
#                      param_algoritmo  param_algoritmo__C  \
# 0  LogisticRegression(solver='saga')               1.000
# 1  LogisticRegression(solver='saga')               1.000
# 2  LogisticRegression(solver='saga')               1.000
# 3  LogisticRegression(solver='saga')               0.750
# 4  LogisticRegression(solver='saga')               0.750
#
#    param_algoritmo__l1_ratio  \
# 0                      1.000
# 1                      0.500
# 2                      0.000
# 3                      1.000
# 4                      0.500
#
#                                               params  split0_test_score  \
# 0  {'algoritmo': LogisticRegression(solver='saga'...              0.692
# 1  {'algoritmo': LogisticRegression(solver='saga'...              0.692
# 2  {'algoritmo': LogisticRegression(solver='saga'...              0.692
# 3  {'algoritmo': LogisticRegression(solver='saga'...              0.692
# 4  {'algoritmo': LogisticRegression(solver='saga'...              0.692
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0              0.703              0.704              0.698              0.703
# 1              0.703              0.704              0.698              0.703
# 2              0.703              0.704              0.698              0.703
# 3              0.703              0.704              0.698              0.703
# 4              0.703              0.704              0.698              0.703
#
#    mean_test_score  std_test_score  rank_test_score
# 0            0.700           0.004                1
# 1            0.700           0.004                2
# 2            0.700           0.004                3
# 3            0.700           0.004                4
# 4            0.700           0.004                5

# %% [markdown]
# Vemos que el resultados del auc es el mismo en todas las primeras configuraciones.
#
# Y reentreamos el modelo con esa configuración.

# %%
#Instanciar
rl = LogisticRegression(solver = 'saga', C = 1, l1_ratio = 1)
#Entrenar
rl.fit(train_x,train_y)
# Out:
# LogisticRegression(C=1, l1_ratio=1, solver='saga')

# %% [markdown]
# Podemos revisar los coefecientes para ver los que son cero y las variables más importantes.

# %%
coeficientes = pd.DataFrame(data = rl.coef_, columns = rl.feature_names_in_).stack().droplevel(level = 0).sort_values()
coeficientes
# Out:
# tipo_interes_mms                       -2.397
# ingresos_mms                           -1.382
# principal_mms                          -1.277
# dti_mms                                -0.472
# finalidad_house                        -0.389
# ingresos_verificados_Not Verified      -0.265
# num_cuotas_ 36 months                  -0.213
# finalidad_other                        -0.171
# vivienda_MORTGAGE                      -0.122
# antigüedad_empleo_oe_mms               -0.078
# finalidad_credit_card                  -0.054
# finalidad_car                          -0.036
# finalidad_vacation                     -0.029
# finalidad_moving                        0.000
# vivienda_OWN                            0.000
# ingresos_verificados_Source Verified    0.000
# num_cuotas_ 60 months                   0.010
# finalidad_home_improvement              0.015
# finalidad_debt_consolidation            0.027
# finalidad_medical                       0.060
# finalidad_major_purchase                0.077
# ingresos_verificados_Verified           0.100
# vivienda_RENT                           0.110
# num_derogatorios_bin                    0.145
# finalidad_small_business                0.288
# porc_uso_revolving_mms                  0.312
# num_lineas_credito_mms                  1.626
# imp_cuota_mms                           1.910
# rating_oe_mms                           4.513
# dtype: float64

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# ### Predecir sobre validación

# %%
pred = rl.predict_proba(val_x)[:, 1]

# %% [markdown]
# ### Evaluar sobre validación

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(val_y, pred)
# Out:
# 0.7014569185629523

# %% [markdown]
# ## REPORTING DEL MODELO

# %% [markdown]
# ### Gain Chart

# %%
def gain_chart(y_true, y_pred, figsize=(8, 6)):
    df_gain = pd.DataFrame({'y': y_true, 'pred': y_pred})
    df_gain = df_gain.sort_values('pred', ascending=False).reset_index(drop=True)

    df_gain['acumulado'] = df_gain['y'].cumsum() / df_gain['y'].sum()
    df_gain['porcentaje_muestra'] = (np.arange(len(df_gain)) + 1) / len(df_gain)

    plt.figure(figsize=figsize)
    plt.plot(df_gain['porcentaje_muestra'], df_gain['acumulado'], label='Modelo')
    plt.plot(df_gain['porcentaje_muestra'], df_gain['porcentaje_muestra'], '--', label='Aleatorio')
    plt.xlabel('Porcentaje de muestra')
    plt.ylabel('Porcentaje acumulado de positivos')
    plt.title('Gain Chart')
    plt.legend()
    plt.grid()
    plt.show()

    return df_gain

# %%
gain_chart(val_y, pred)
# Out:
#        y  pred  acumulado  porcentaje_muestra
# 0      1 0.661      0.000               0.000
# 1      0 0.659      0.000               0.000
# 2      0 0.636      0.000               0.000
# 3      1 0.635      0.000               0.000
# 4      0 0.623      0.000               0.000
# ...   ..   ...        ...                 ...
# 41878  0 0.014      1.000               1.000
# 41879  0 0.013      1.000               1.000
# 41880  0 0.013      1.000               1.000
# 41881  0 0.012      1.000               1.000
# 41882  0 0.011      1.000               1.000
#
# [41883 rows x 4 columns]

# %% [markdown]
# ### Lift Chart

# %%
def lift_chart(y_true, y_pred):
    df = pd.DataFrame({'y': y_true, 'pred': y_pred})
    df = df.sort_values('pred', ascending=False).reset_index(drop=True)
    total_positivos = df['y'].sum()
    total_muestra = len(df)
    porcentaje_muestra = np.arange(1, total_muestra + 1) / total_muestra
    acumulado_positivos = df['y'].cumsum()
    lift_acumulado = (acumulado_positivos / porcentaje_muestra) / total_positivos

    plt.figure(figsize=(8,6))
    plt.plot(porcentaje_muestra, lift_acumulado, label='Modelo', color='green')
    plt.axhline(1, color='black', linestyle='--', label='Aleatorio')
    plt.xlabel('Porcentaje de muestra')
    plt.ylabel('Lift acumulado')
    plt.title('Lift Curve')
    plt.legend()
    plt.grid()
    plt.show()

# %%
lift_chart(val_y, pred)

# %% [markdown]
# ### ROC Chart

# %%
def roc_curve(y_true, y_pred, n_thresholds=100):
    df = pd.DataFrame({'y': y_true, 'pred': y_pred})
    thresholds = np.linspace(0, 1, n_thresholds)
    tpr = []
    fpr = []
    total_pos = (df['y'] == 1).sum()
    total_neg = (df['y'] == 0).sum()
    for thresh in thresholds:
        y_pred_bin = (df['pred'] >= thresh).astype(int)
        tp = ((df['y'] == 1) & (y_pred_bin == 1)).sum()
        fp = ((df['y'] == 0) & (y_pred_bin == 1)).sum()
        tpr.append(tp / total_pos if total_pos > 0 else 0)
        fpr.append(fp / total_neg if total_neg > 0 else 0)
    tpr = np.array(tpr)
    fpr = np.array(fpr)

    plt.figure(figsize=(8,6))
    plt.plot(fpr, tpr, color='green', label='Modelo')
    plt.plot([0,1], [0,1], '--', color='black', label='Aleatorio')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    plt.grid()
    plt.show()

# %%
roc_curve(val_y, pred)
